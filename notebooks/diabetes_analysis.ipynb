# %% [markdown]
# # Diabetes Predictions Ml Analysis
#
# This notebook walks through a complete machine learning pipeline for predicting diabetes using logistic regression.
#
# **Steps:**
# 1. Load and explore data
# 2. Preprocess features
# 3. Train model
# 4. Evaluate results

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd 
import numpy as np
