# %% [markdown]
# # Machine Learning Notebook
#
# A simple notebook for machine learning experiments

# %% [markdown]
# ## Setup

# %%
# Import Libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

print("Libraries imported sucessfully")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # Import Libraries
# ----> 2 import pandas as pd
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %% [markdown]
# # Load Data

# %%
# Example: Load your dataset here 
# data = pd.read_csv('your_data.csv')
# data.head()

print("Ready to load data")
# Out:
# Ready to load data

# %% [markdown]
# ## Explore Data

# %%
# Example: Explore your data 
# data.info()
# data.describe()

print("Add yout data exploration code here")
# Out:
# Add yout data exploration code here
